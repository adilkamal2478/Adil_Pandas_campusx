# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkamal2478/Adil_Pandas_campusx/blob/main/Pandas_my_notes_session_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Required files
#
# 1. subs.csv
# 2. bollywood.csv
# 3. kohli_ipl.csv

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']
country
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]
ser_run = pd.Series(runs)
ser_run
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Adil ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Adil ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks , name="Adil ke marks hai bhaisahab")
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Adil ke marks hai bhaisahab, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size  (number of rows )
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Adil ke marks hai bhaisahab'

# %%
# is_unique
marks_series.is_unique

print(pd.Series([1,1,2,3,4,5]).is_unique)   #  duplicate values
print(pd.Series([10,11,12]).is_unique)      # unique values
# Out:
# False
# True

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
ser_run.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col

subs = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/subs.csv')   # it is in dataframe
print(subs)
print(type(subs))

subs = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/subs.csv').squeeze('columns')  # now converted to series
print(subs)
print(type(subs))
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# with 2 cols

vk = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/kohli_ipl.csv' , index_col = 'match_no').squeeze("columns")
print(vk)
print(type(vk))
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
movies = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/bollywood.csv' , index_col = 'movie').squeeze('columns')
print(movies)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()    # by default top 5 rows
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.tail()   # by default last 5 rows
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
print(vk.head(12))     # specific amount of top rows
print(vk.tail(3))      # specific mount of bottom rows
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# Name: runs, dtype: int64
# match_no
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample()     # gives random 1 row
movies.sample(5)     # gives random 5 row
# Out:
# movie
# Nautanki Saala!             Ayushmann Khurrana
# Just Married (2007 film)          Fardeen Khan
# Battalion 609                      Vicky Ahuja
# Baghban (2003 film)           Amitabh Bachchan
# Kai Po Che!                      Rajkummar Rao
# Name: lead, dtype: object

# %%
# value_counts -> movies

movies.value_counts()     # frequency of all actor movies
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
movies.value_counts()['Akshay Kumar']   # no. of movies of akshay kumar
# Out:
# np.int64(48)

# %%
# sort_values -> inplace
print(vk.sort_values(ascending=False).head(1).values[0])     # vk highest score

# NOTE - these changes are temprory , if u want a permanent chnage then use inplace

# vk.short_values(inplace = True)    # use it very carefully
# Out:
# 113

# %%
# sort_index -> inplace -> movies
# movies.sort_index(ascending=False,inplace=True)   # use inplace very carefully
movies.sort_index(ascending=False)
# print(movies)
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)              Arjun Kapoor
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()    # total no. of items present in the series (only non-missing values)
# Out:
# np.int64(215)

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
print('Mean ->',subs.mean())
print('Median ->',vk.median())
print('Mode ->',movies.mode())
print('Std ->',subs.std())
print('Var ->',vk.var())
# Out:
# Mean -> 135.64383561643837
# Median -> 24.0
# Mode -> 0    Akshay Kumar
# Name: lead, dtype: object
# Std -> 62.67502303725269
# Var -> 688.0024777222344

# %%
# min/max
print('Max:',subs.max())
print('Min:',subs.min())
# Out:
# Max: 396
# Min: 33

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
print(x)
print('value:',x[2])
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64
# value: 14

# %% [markdown]
# **NOTE**
#
# x[-1] → works only if -1 is an actual index label or the idexes are in string in your Series. Otherwise it will throw type error.
#
# eg. vk has indexing from 0 to 200 so if we use vk[-1] it will throw error
#
# movies has indexs in string so movies[-1] will give u output

# %%
# negative indexing (doesnot work on negative indexing)
# x[-1]     # Error

x.iloc[-1]    # use this instead
# Out:
# np.int64(9)

# %%
movies
movies[0]
movies['Why Cheat India']
# Out:
# /tmp/ipykernel_864/612877957.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[0]
# 'Emraan Hashmi'

# %%
# slicing (same as python slicing)
vk[5:16]    # 5 to 15 index
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:]   # last 5
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[::2]     # all alternate movies (means 1,3,5..)(gap of 1)
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
vk[[1,3,4,5]]     # 1st 3st 4th 5th match scores
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ### Editing Series
#
# Honestly we donot use editing most of the time , we only read data

# %%
# using indexing
marks_series[1] = 100   # marks of english subject updated to 100
marks_series
# Out:
# /tmp/ipykernel_864/3965096885.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100   # marks of english subject updated to 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Adil ke marks hai bhaisahab, dtype: int64

# %%
# what if an index does not exist

# print(marks_series['evs'])    # throw an error bcz evs not present
marks_series['evs'] = 95
marks_series                    # now evs added in the bottom
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# evs         95
# Name: Adil ke marks hai bhaisahab, dtype: int64

# %%
# slicing

ser_run
ser_run[2:4] = [99,99]    # index 2,3 updated to 99,99
ser_run
# Out:
# 0     13
# 1     24
# 2     99
# 3     99
# 4    100
# dtype: int64

# %%
# fancy indexing

ser_run
ser_run[[0,3,4]] = 0    # 0th 3rd 4th edited to 0
ser_run
# Out:
# 0     0
# 1    24
# 2    99
# 3     0
# 4     0
# dtype: int64

# %%
# using index label
movies
movies['Uri: The Surgical Strike'] = 'Adil kamal'
movies
# Out:
# movie
# Uri: The Surgical Strike                      Adil kamal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min

print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
marks_series
list(marks_series)
# Out:
# [67, 100, 89, 100, 95]

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(100),
#  'science': np.int64(89),
#  'hindi': np.int64(100),
#  'evs': np.int64(95)}

# %%
# membership operator (Return True if found in index , (not in the value only index))

movies
# 'Adil kamal' in movies          # False (bcz it is value not index)
# 'Vicky Ahuja' in movies         # False (bcz it is value not index)

'Saathiya (film)' in movies   # True (present in the index)
# Out:
# True

# %%
# if u wanna seaarch in values then use .values

'Adil kamal' in movies.values   # True
# Out:
# True

# %%
# looping

# for i in movies:
#   print(i)        # all values(actor name) will print (no index)

for i in movies.index:
  print(i)        # all index(movie name) will print (no index)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)

print(100 + marks_series)
print(100 - marks_series)   # u can use all arithmetic operations
# Out:
# maths      167
# english    200
# science    189
# hindi      200
# evs        195
# Name: Adil ke marks hai bhaisahab, dtype: int64
# maths      33
# english     0
# science    11
# hindi       0
# evs         5
# Name: Adil ke marks hai bhaisahab, dtype: int64

# %%
# Relational Operators

vk >=50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli

vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/kohli_ipl.csv',index_col='match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/drive/MyDrive/Pandas_CampusX/Session_16/bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 10478

# %%
# between

vk.between(51,99)       # both are included
vk[vk.between(51,99)]
vk[vk.between(51,99)].size

# %%
# clip  ( make all values between a given range )
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates()    # first occurance was preserved and 2nd or last occurance deleted
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')   # now first occurance deleted
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
movies  # 1500 rows
movies.drop_duplicates()    # 566 rows
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
# duplicated  (gives a boolean data of which row is duplicate which is no)

temp.duplicated()   # false meaans 1st occurance , True means Duplicate

temp.duplicated().sum()   # total no. of duplicate value
# Out:
# np.int64(4)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %% [markdown]
# **.size VS .count()**

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size   #(counted all nan values also)
# Out:
# 10

# %%
temp.count()    # (not counted nan values)
# Out:
# np.int64(7)

# %%
# isnull
vk.isnull().sum()   # 0 missing values
temp.isnull().sum()   # 3 missing values
# Out:
# np.int64(3)

# %%
# dropna

temp.dropna()   # all missing values dropped
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna

temp.fillna(100)    # missing values replaced with 100
temp.fillna(temp.mean())    # missing values replaced with mean of data means 5
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin

(vk == 49) | (vk == 99)
vk[(vk == 49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk.isin([49,99])
vk[vk.isin([49,99])]    # same output as above
vk[vk.isin([49,79,99])]    # we can use multiple values in it
# Out:
# match_no
# 82     99
# 86     49
# 117    79
# Name: runs, dtype: int64

# %%
# apply (very very useful fuction)
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split())
# Out:
# movie
# Uri: The Surgical Strike                   [Vicky, Kaushal]
# Battalion 609                                [Vicky, Ahuja]
# The Accidental Prime Minister (film)         [Anupam, Kher]
# Why Cheat India                            [Emraan, Hashmi]
# Evening Shadows                         [Mona, Ambegaonkar]
#                                                ...
# Hum Tumhare Hain Sanam                   [Shah, Rukh, Khan]
# Aankhen (2002 film)                     [Amitabh, Bachchan]
# Saathiya (film)                             [Vivek, Oberoi]
# Company (film)                                [Ajay, Devgn]
# Awara Paagal Deewana                        [Akshay, Kumar]
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head()
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 99     # fist run changed to 99
new
vk              # unfortunately it also changed in vk bcz .head() doesnot get a
                # copy ofdata it gets a view of data
# Out:
# match_no
# 1      99
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head().copy()
new
# Out:
# match_no
# 1    99
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 100
new             # new chnaged to 100
vk              # but vk is original one 99
# Out:
# match_no
# 1      99
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
