# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkamal2478/Adil_Pandas_campusx/blob/main/Seaborn_my_notes_session_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Why Seaborn?
#
# - provides a layer of abstraction hence simpler to use
# - better aesthetics
# - more graphs included

# %% [markdown]
# ### Seaborn Roadmap
#
# Types of Functions
#
# - Figure Level
# - Axis Level
#
# Main Classification
#
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots
#
# https://seaborn.pydata.org/api.html

# %% [markdown]
# ### 1. Relational Plot
#
# - to see the statistical relation between 2 or more variables.
# - Bivariate Analysis
#
# Plots under this section
#
# - scatterplot
# - lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ###Some popular data sets present in seaborn
#
# `iris`
#
# `titanic`
#
# `tips`
#
# `diamonds`
#
# `dowjones`
#
# `anscombe`
#
# `flights`

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# scatter plot -> axes level function
sns.scatterplot(data = tips , x = 'total_bill' , y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# hue , style , size
# hue - use for grouping the values on the basis of a column ,  and then represent it in different colors(male , female)
# style - different stules of dots will appear according to the given column
# size - dot size represnts the amount pr size

sns.scatterplot(
    data = tips ,
    x = 'total_bill' ,
    y = 'tip' ,
    hue = 'sex' ,
    style = 'time',
    size='size'
    )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot -> figure level -> square shape

sns.relplot(data = tips , x = 'total_bill' , y = 'tip' , kind = 'scatter')

# %%
sns.relplot(
    data = tips ,
    x = 'total_bill' ,
    y = 'tip',
    hue = 'sex',
    style = 'time',
    size = 'size'
    )

# %% [markdown]
# ###NOTE - Most of the time , use the figure level function like relplot
#
# ### Axes level function comes under figures , figure is on the top

# %%
# line plot

gap = px.data.gapminder()
temp_df = gap[gap['country'] == 'India']
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
# axes level function

sns.lineplot(data = temp_df , x = 'year' , y = 'lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# using relplot - figure level function

sns.relplot(data = temp_df , x = 'year' , y = 'lifeExp' , kind = 'line')

# %%
temp_df = gap[gap['country'].isin(['India' , 'Brazil' , 'Germany'])]
temp_df
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# 564  Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406    82400996  32170.374420       DEU
# 696    India      Asia  1952   37.373   372000000    546.565749       IND
# 697    India      Asia  1957   40.249   409000000    590.061996       IND
# 698    India      Asia  1962   43.605   454000000    658.347151       IND
# 699    India      Asia  1967   47.193   506000000    700.770611       IND
# 700    India      Asia  1972   50.651   567000000    724.032527       IND
# 701    India      Asia  1977   54.208   634000000    813.337323       IND
# 702    India      Asia  1982   56.596   708000000    855.723538       IND
# 703    India      Asia  1987   58.553   788000000    976.512676       IND
# 704    India      Asia  1992   60.223   872000000   1164.406809       IND
# 705    India      Asia  1997   61.765   959000000   1458.817442       IND
# 706    India      Asia  2002   62.879  1034172547   1746.769454       IND
# 707    India      Asia  2007   64.698  1110396331   2452.210407       IND
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76
# 173       76
# 174       76
# 175       76
# 176       76
# 177       76
# 178       76
# 179       76
# 564      276
# 565      276
# 566      276
# 567      276
# 568      276
# 569      276
# 570      276
# 571      276
# 572      276
# 573      276
# 574      276
# 575      276
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %% [markdown]
# ### One more difference between axes and figure is that , figure put the lagend outside the graph , and axes put the lagen inside the graph

# %%
# hue -> style
# figure level
sns.relplot(
    kind = 'line' ,
    data  =temp_df ,
    x = 'year' ,
    y = 'lifeExp' ,
    hue = 'country',
    style = 'continent',
    size = 'continent'          # thickness of the line
    )

# %%
# axes level

sns.lineplot(data=temp_df, x='year', y='lifeExp', hue='country')

# see , lagend is inside the graph
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# facet plot -> figure level function -> work with relplot
# it will not work with scatterplot and lineplot

sns.relplot(
    data = tips,
    x = 'total_bill',
    y = 'tip',
    kind = 'scatter',
    row = 'day',
    col = 'smoker',

    hue = 'sex',
    style = 'day',
    size = 'size'
    )


# col - it mean it makes columns by seeing the smoker column (2 column , for yes and no)
# row - it makes rows according to day (4 rows , thur fri sat sun)

# we can also use hue and style and size

# %%
# col wrap

sns.relplot(
    data = gap ,
    x = 'lifeExp' ,
    y = 'gdpPercap' ,
    kind = 'scatter',
    col = 'year',
    col_wrap=3,
    )


# col_wrap = 4 - means make only 4 columns , if columns increased from 4 , then wrap it below

# %% [markdown]
# ### 2. Distribution Plots
#
# - used for univariate analysis
# - used to find out the distribution
# - Range of the observation
# - Central Tendency
# - is the data bimodal?
# - Are there outliers?
#
# Plots under distribution plot
#
# - histplot
# - kdeplot
# - rugplot

# %%
# figure level -> displot
# axes level -> histplot -> kdeplot -> rugplot

# %%
# plotting univariate histogram

# by histplot

sns.histplot(data = tips , x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# by distplot - it is figure level

sns.displot(data=tips , x = 'total_bill' , kind ='hist')

# %%
# bins parameter

sns.displot(
    data=tips ,
    x = 'total_bill' ,
    kind ='hist',
    bins =40

    )

# %%
# It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram.
# Discrete bins are automatically set for categorical variables

# it is like a countplot

sns.displot(
    data = tips ,
    x = 'day' ,
    kind = 'hist',

    )

# %%
# hue parameter

sns.displot(
    data=tips ,
    x = 'total_bill' ,
    kind ='hist',
    bins =40,
    hue='sex'

    )

# %%
# element -> step

sns.displot(
    data=tips ,
    x = 'total_bill' ,
    kind ='hist',
    bins =40,
    hue = 'sex',
    element='step'

    )

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.displot(
    data=titanic,
    x='age',
    kind='hist',
    element='step',
    hue='sex')

# %%
# faceting using col and row -> not work on histplot function

sns.displot(
    data = titanic ,
    x = 'age' ,
    kind = 'hist',
    element = 'step',
    hue = 'sex',
    col = 'sex'
    )

# %%
# kdeplot - axes level
# Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate

sns.kdeplot(
    data = tips,
    x='total_bill'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# figure level

sns.displot(
    kind = 'kde',
    data = tips,
    x = 'total_bill'
)

# %%
# hue -> fill

sns.displot(
    kind = 'kde',
    data = tips,
    x = 'total_bill',
    hue  ='sex',
    fill = True
)

# %%
# Rugplot

# Plot marginal distributions by drawing ticks along the x and y axes.

# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.

sns.kdeplot(data = tips,x = 'total_bill')
sns.rugplot(data = tips,x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot
# and then shows the count of observations within each rectangle with the fill color

sns.displot(
    kind = 'hist',
    data = tips,
    x = 'total_bill' ,
    y = 'tip'
)

# it is a 2d histogram ,  where both histogram from x axis and y axis collides there will be a block in the below pic
# the darker the block , the more data present there

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian

sns.displot(
    kind = 'kde',
    data = tips,
    x = 'total_bill',
    y = 'tip'
)

# %% [markdown]
# ### 2. Matrix Plot
#
# - Heatmap
# - Clustermap

# %%
# Heatmap

# Plot rectangular data as a color-encoded matrix
gap
temp_df = gap.pivot(index = 'country' , columns = 'year' , values = 'lifeExp')

# axes level function

plt.figure(figsize=(15,15))
sns.heatmap(
    data = temp_df
)


# NOTE - it canot have any figure level func , it only have axes
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot

temp = gap[gap['continent'] == 'Europe'].pivot(index = 'country' , columns = 'year' , values='lifeExp')
temp
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
