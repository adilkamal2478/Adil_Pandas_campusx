# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkamal2478/Adil_Pandas_campusx/blob/main/Session_23_my_task_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
from matplotlib.lines import lineStyles
temp1 = df[df['Country'] == 'Iran']
temp2 = df[df['Country'] == 'China']
temp1 = temp1.groupby('Year')['PM2.5'].sum().reset_index()
temp2 = temp2.groupby('Year')['PM2.5'].sum().reset_index()

plt.plot(temp1['Year'] , temp1['PM2.5'] , linestyle = 'dashed' , linewidth = 3 , label = 'Iran')
plt.plot(temp2['Year'] , temp2['PM2.5'] ,  linewidth = 3 , label = 'China')

plt.xticks(df['Year'])
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.title('PM2.5 Over the years')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
df.head(3)
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018

# %%
plt.hist(df['PM10'] ,bins = 50  , density = True)
plt.xlabel('Bins')
plt.ylabel('Probability')
plt.title('Histogram of PM10')
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
df.head()
poland = df[df['Country'] == 'Poland']
chile = df[df['Country'] == 'Chile']

# %%
plt.scatter(poland['PM2.5'] , poland['PM10'] , marker = 'D' , color = 'red' ,label='Poland' )
plt.scatter(chile['PM2.5'] , chile['PM10'] , marker = '+' , color = 'black'  ,label='Chile')

plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM2.5 Vs PM10 for Chile and Poland')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
df
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# 1                >75%   316                 NaN                     2018
# 2          50% -< 75%   275                 NaN                     2018
# 3                >75%   260                 NaN                     2018
# 4                >75%   266                 NaN                     2018
# ..                ...   ...                 ...                      ...
# 495              >75%    31                >75%                     2018
# 496              >75%    29                >75%                     2018
# 497              >75%    35                >75%                     2018
# 498        50% -< 75%    59                 NaN                     2018
# 499              >75%    56                >75%                     2018
#
# [500 rows x 10 columns]

# %%
temp = df.groupby('Country')['Position'].count().sort_values(ascending=False).head(5).reset_index()
temp
# Out:
#   Country  Position
# 0   China       283
# 1    Iran        43
# 2   India        32
# 3   Chile        19
# 4  Poland        17

# %%
plt.pie(temp['Position'] , labels= temp['Country'] , autopct = '%0.1f%%')

plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
temp = df.groupby('Country')['Position'].count().sort_values(ascending=False).head(5).reset_index()
temp
# Out:
#   Country  Position
# 0   China       283
# 1    Iran        43
# 2   India        32
# 3   Chile        19
# 4  Poland        17

# %%
plt.bar(temp['Country'] , temp['Position'])
plt.xlabel('Country')
plt.ylabel('Frequency Count')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')

df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'] , df['total_profit'] , linestyle = 'dotted' , color = 'blue' , marker = 'o' ,label='Month on month Profit')
plt.xticks(df['month_number'])
plt.xlabel('month')
plt.ylabel('Totoal profit')
plt.title('Company sales profit')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
temp = df[df['month_number'] == 3]
temp
temp = temp.drop(['total_profit' , 'total_units' , 'month_number'], axis=1)
temp
# Out:
#    facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# 2       2140      1340        4550         9550     3550         1340

# %%
temp = temp.T
temp
# Out:
#                 2
# facecream    2140
# facewash     1340
# toothpaste   4550
# bathingsoap  9550
# shampoo      3550
# moisturizer  1340

# %%
plt.pie(temp[2] , labels = temp.index , autopct='%0.1f%%' , explode = [0,0,0.1,0,0,0] , shadow=True)
plt.title("Sales in March")
plt.show()

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'] , df['facecream'] , label = 'facecream' , marker='o' ,linewidth=3 , linestyle = 'solid')
plt.plot(df['month_number'] , df['facewash'] , label = 'facewash' , marker='o' ,linewidth=3 , linestyle ='dashed')
plt.plot(df['month_number'] , df['toothpaste'] , label = 'toothpaste' , marker='o' ,linewidth=3 , linestyle = 'dashdot')
plt.plot(df['month_number'] , df['bathingsoap'] , label = 'bathingsoap' , marker='o' ,linewidth=3 , linestyle = 'dotted')
plt.plot(df['month_number'] , df['shampoo'] , label = 'shampoo' , marker='o' ,linewidth=3)
plt.plot(df['month_number'] , df['moisturizer'] , label = 'moisturizer' , marker='o' ,linewidth=3)

plt.xticks(df['month_number'])
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
df['quarter'] = [1,1,1,2,2,2,3,3,3,4,4,4]
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit  quarter
# 0          1500        21100        211000        1
# 1          1200        18330        183300        1
# 2          1340        22470        224700        1
# 3          1130        22270        222700        2
# 4          1740        20960        209600        2
# 5          1555        20140        201400        2
# 6          1120        29550        295500        3
# 7          1400        36140        361400        3
# 8          1780        23400        234000        3
# 9          1890        26670        266700        4
# 10         2100        41280        412800        4
# 11         1760        30020        300200        4

# %%
new = df.groupby('quarter')[['facecream', 'facewash', 'toothpaste', 'bathingsoap','shampoo', 'moisturizer', 'total_units']].sum()
new
# Out:
#          facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  \
# quarter
# 1             7270      4040       14850        24850     6850         4040
# 2             9760      4425       15320        24120     5320         4425
# 3            10220      4300       16740        27040     6740         4300
# 4             7230      5750       23000        38000     6500         5750
#
#          total_units
# quarter
# 1              61900
# 2              63370
# 3              89090
# 4              97970

# %%
plt.bar(new.index-0.30 , new['facecream'] , width = 0.15, color= 'blue' ,label='facecream')
plt.bar(new.index-0.15 , new['facewash'] , width = 0.15 ,color= 'orange' ,label='facewash')
plt.bar(new.index , new['toothpaste'] , width = 0.15, color= 'green' ,label='toothpaste')
plt.bar(new.index+0.15 , new['bathingsoap'] , width = 0.15, color = 'red' ,label= 'bathingsoap')
plt.bar(new.index+0.30 , new['shampoo'] , width = 0.15, color = 'purple' ,label='shampoo')
plt.bar(new.index+0.45 , new['moisturizer'] , width = 0.15, color = 'brown' ,label='moisturizer')

plt.xticks(new.index)
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()
