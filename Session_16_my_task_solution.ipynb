# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkamal2478/Adil_Pandas_campusx/blob/main/Session_16_my_task_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### `Q-1:` Write a program to create an empty series.

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### `Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
x = pd.Series([1,2,3,4])
y = pd.Series([10,11,12,13])

print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 0    11
# 1    13
# 2    15
# 3    17
# dtype: int64
# 0   -9
# 1   -9
# 2   -9
# 3   -9
# dtype: int64
# 0    10
# 1    22
# 2    36
# 3    52
# dtype: int64
# 0    0.100000
# 1    0.181818
# 2    0.250000
# 3    0.307692
# dtype: float64

# %% [markdown]
# ### `Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
x = pd.Series([2, 4, 6, 8, 10])
y = pd.Series([1, 3, 5, 7, 10])

print(x==y)
print(x > y)
print(x < y)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ### `Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
x = pd.Series([1,2,'Python', 2.0, True, 100])
x

def change(series ):
  return pd.to_numeric(series , errors='coerce')


change(x)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# ### `Q-6` Find top 10 most run getter from the series.

# %%
data = pd.read_csv("/content/drive/MyDrive/Pandas_CampusX/Session_16_task/batsman_runs_series.csv").squeeze('columns')
data

runs_series = data.set_index("batter")["batsman_run"]   # converted to series
runs_series
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %%
runs_series.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ### `Q-7` No of players having runs above 3000

# %%
runs_series[runs_series > 3000 ].count()
# Out:
# np.int64(20)

# %% [markdown]
# ### `Q-8` No of players having runs above mean value?

# %%
runs_series[runs_series > runs_series.mean() ].count()
# Out:
# np.int64(128)

# %% [markdown]
# ### `Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     iii. Item price is given in $, so convert it to rupees without currency symbol.
#     iv. Make data type of newly made series as float.
#     v. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# i. Read `items.csv` making `item_name` as index.

item = pd.read_csv("/content/drive/MyDrive/Pandas_CampusX/Session_16_task/items.csv").squeeze('columns')
item

item = item.set_index("item_name")["item_price"]
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
# ii. Show no of nan values

item.isna().sum()
# Out:
# np.int64(50)

# %%
# ii. Item price is given in $, so convert it to rupees without currency symbol.
item = item.astype(str)
item = item.str.replace('$' , '')        # $ is removed

item = item.astype(float)
item = round(item * (94.44))
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              226.0
# Izze                                      320.0
# Nantucket Nectar                          320.0
# Chips and Tomatillo-Green Chili Salsa     226.0
# Chicken Bowl                             1604.0
#                                           ...
# Steak Burrito                            1110.0
# Steak Burrito                            1110.0
# Chicken Salad Bowl                       1062.0
# Chicken Salad Bowl                        826.0
# Chicken Salad Bowl                        826.0
# Name: item_price, Length: 4622, dtype: float64

# %%
# iv. Make data type of newly made series as float.
item = item.astype(float)

# %%
# v. Fill nan with mean of the series
item.fillna(item.mean())
# Out:
# item_name
# Chips and Fresh Tomato Salsa              226.0
# Izze                                      320.0
# Nantucket Nectar                          320.0
# Chips and Tomatillo-Green Chili Salsa     226.0
# Chicken Bowl                             1604.0
#                                           ...
# Steak Burrito                            1110.0
# Steak Burrito                            1110.0
# Chicken Salad Bowl                       1062.0
# Chicken Salad Bowl                        826.0
# Chicken Salad Bowl                        826.0
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ### `Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# i. Find mean price
item.mean()
# Out:
# np.float64(704.7954943132108)

# %%
# ii. Find 30th and 6th percentile value
item.quantile(q=0.3)
item.quantile(q=0.06)
# Out:
# np.float64(118.0)

# %%
# iii. Plot Histogram on price with bin size 50

item.plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# iv. No of items price lies between [1000 to 2000]
item[item.between(1000,2000)].count()
# Out:
# np.int64(1066)
